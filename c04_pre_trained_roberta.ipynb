# %%
from transformers import pipeline

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# Replace this with your own checkpoint
model_checkpoint = "/content/gdrive/MyDrive/Transformers_files/scratch_roberta_squad"
 
prueba_modelo_roberta = pipeline("question-answering", model=model_checkpoint)

# %%
def modelo_pre_trained_roberta(question, context):

  respuesta_modelo = prueba_modelo_roberta(question=question, context=context)
  respuesta = respuesta_modelo['answer']
  score = str(np.round(respuesta_modelo['score'], 5))

  return respuesta + '  (score=' + score+ ')'
