# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd "/content/gdrive/MyDrive/Colab Notebooks"
# %run 'c01_proces_texto_en.ipynb'
# Out:
# /content/gdrive/MyDrive/Colab Notebooks

# %%
def chat(modelo_transformers):
  
  print('Wiki Assistant 👩‍🏫: Hello 😊, I am your virtual assistant from Wikipedia. What topic would you like to consult? (Write exit if you want to close the chat)')
  msg = input('           You 👉: ')
  print(' ')

  if 'exit' not in msg.lower():
    
    texto = procesamiento_tema(msg)
    print('Wiki Assistant 👩‍🏫: What would you like to know?')
    msg = input('           You 👉: ')
     
  while 'exit' not in msg.lower():

    if 'to change the topic' in msg.lower():

      print('Wiki Assistant 👩‍🏫: Of course😊, What other topic would you like to consult?')
      msg = input('           You 👉: ')
      print(' ')
      # msg = traductor_es_en(msg)
      texto = procesamiento_tema(msg)
      print('Wiki Assistant 👩‍🏫: What would you like to know?')
      msg = input('           You 👉: ')
      
    else:
      
      # msg = traductor_es_en(msg)
      respuesta = modelo_transformers(msg, texto)
      # respuesta = traductor_es_en(respuesta)
      print('Wiki Assistant 👩‍🏫: ' + respuesta)
      print(' ')
      msg = input('           You 👉: ')

# %% [markdown]
# # Pipeline Roberta

# %%
# %run 'c02_pipeline_roberta.ipynb'

# %%
chat(modelo_roberta_pipeline)
# Out:
# Wiki Assistant 👩‍🏫: Hello 😊, I am your virtual assistant from Wikipedia. What topic would you like to consult? (Write exit if you want to close the chat)
#            You 👉: 2021 Formula One World Championship
#
# Wiki Assistant 👩‍🏫: What would you like to know?
#            You 👉: who driver took pole position in Spain?
# Wiki Assistant 👩‍🏫: Lewis Hamilton  (score=0.19071)
#
#            You 👉: What was the budget cap?
# Wiki Assistant 👩‍🏫: teams limited to spending a maximum of $145 million per year  (score=0.07829)
#
#            You 👉: Who is the race director?
# Wiki Assistant 👩‍🏫: Michael Masi  (score=0.96012)
#
#            You 👉: how many grand prix were in 2021?
# Wiki Assistant 👩‍🏫: twenty-two  (score=0.8594)
#
#            You 👉: Who won the Formula One Driver's Championship?
# Wiki Assistant 👩‍🏫: Verstappen  (score=0.59016)
#
#            You 👉: Wich team won the constructor's championship?
# Wiki Assistant 👩‍🏫: Mercedes  (score=0.79485)
#
# ...

# %%
chat(modelo_roberta_pipeline)
# Out:
# Wiki Assistant 👩‍🏫: Hello 😊, I am your virtual assistant from Wikipedia. What topic would you like to consult? (Write exit if you want to close the chat)
#            You 👉: Amazon Alexa
#
# Wiki Assistant 👩‍🏫: What would you like to know?
#            You 👉: What is Alexa?
# Wiki Assistant 👩‍🏫: a virtual assistant technology  (score=0.34341)
#
#            You 👉: Why her name is Alexa?
# Wiki Assistant 👩‍🏫: reminiscent of the Library of Alexandria  (score=0.13018)
#
#            You 👉: What inspired the creation of Alexa?
# Wiki Assistant 👩‍🏫: a Polish speech synthesiser named Ivona  (score=0.22005)
#
#            You 👉: I would like to change the topic
# Wiki Assistant 👩‍🏫: Of course😊, What other topic would you like to consult?
#            You 👉: Tayrona National Natural Park
#
# Wiki Assistant 👩‍🏫: What would you like to know?
#            You 👉: Where is it located?
# Wiki Assistant 👩‍🏫: Colombian Caribbean  (score=0.09539)
#
#            You 👉: When was created?
# ...

# %% [markdown]
# # Pipeline T5

# %%
# %run 'c03_pipeline_T5.ipynb'
# Out:
# Downloading:   0%|          | 0.00/793 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.20k [00:00<?, ?B/s]

# %%
chat(modelo_T5_pipeline)
# Out:
# Wiki Assistant 👩‍🏫: Hello 😊, I am your virtual assistant from Wikipedia. What topic would you like to consult? (Write exit if you want to close the chat)
#            You 👉: 2021 Formula One World Championship
#
# Wiki Assistant 👩‍🏫: What would you like to know?
#            You 👉: who driver took pole position in Spain?
# Wiki Assistant 👩‍🏫: Max Verstappen
#
#            You 👉: What was the budget cap?
# Wiki Assistant 👩‍🏫: twenty-two Grands Prix
#
#            You 👉: Who is the race director?
# Wiki Assistant 👩‍🏫: Michael Masi,
#
#            You 👉: how many grand prix were in 2021?
# Wiki Assistant 👩‍🏫: over twenty-two
#
#            You 👉: Who won the Formula One Driver's Championship?
# Wiki Assistant 👩‍🏫: Max Verstappen
#
#            You 👉: Wich team won the constructor's championship?
# Wiki Assistant 👩‍🏫: Autodrivers
#
#            You 👉: I would like to change the topic
# Wiki Assistant 👩‍🏫: Of course😊, What other topic would you like to consult?
# ...

# %%
chat(modelo_T5_pipeline)
# Out:
# Wiki Assistant 👩‍🏫: Hello 😊, I am your virtual assistant from Wikipedia. What topic would you like to consult? (Write exit if you want to close the chat)
#            You 👉: Amazon Alexa
#
# Wiki Assistant 👩‍🏫: What would you like to know?
#            You 👉: What is Alexa?
# Wiki Assistant 👩‍🏫: virtual assistant technology largely based on a Polish speech synthesiser
#
#            You 👉: Why her name is Alexa?
# Wiki Assistant 👩‍🏫: it has a hard consonant with the X
#
#            You 👉: What inspired the creation of Alexa?
# Wiki Assistant 👩‍🏫: computer voice and conversational system
#
#            You 👉: I would like to change the topic
# Wiki Assistant 👩‍🏫: Of course😊, What other topic would you like to consult?
#            You 👉: Tayrona National Natural Park
#
# Wiki Assistant 👩‍🏫: What would you like to know?
#            You 👉: Where is it located?
# Wiki Assistant 👩‍🏫: the jurisdiction of the Santa Marta municipality
#
#            You 👉: When was created?
# ...

# %% [markdown]
# # Pre entrenado Roberta

# %%
# %run 'c04_pre_trained_roberta.ipynb'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# All model checkpoint layers were used when initializing TFRobertaForQuestionAnswering.
#
# All the layers of TFRobertaForQuestionAnswering were initialized from the model checkpoint at /content/gdrive/MyDrive/Transformers_files/scratch_roberta_squad.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForQuestionAnswering for predictions without further training.

# %%
chat(modelo_pre_trained_roberta)
# Out:
# Wiki Assistant 👩‍🏫: Hello 😊, I am your virtual assistant from Wikipedia. What topic would you like to consult? (Write exit if you want to close the chat)
#            You 👉: 2021 Formula One World Championship
#
# Wiki Assistant 👩‍🏫: What would you like to know?
#            You 👉: who driver took pole position in Spain?
# Wiki Assistant 👩‍🏫: Max Verstappen  (score=0.8586)
#
#            You 👉: What was the budget cap?
# Wiki Assistant 👩‍🏫: teams limited to spending a maximum of $145 million per year  (score=0.37516)
#
#            You 👉: Who is the race director?
# Wiki Assistant 👩‍🏫: Michael Masi  (score=0.99435)
#
#            You 👉: how many grand prix were in 2021?
# Wiki Assistant 👩‍🏫: twenty-two  (score=0.86819)
#
#            You 👉: Who won the Formula One Driver's Championship?
# Wiki Assistant 👩‍🏫: Max Verstappen  (score=0.79452)
#
#            You 👉: Wich team won the constructor's championship?
# Wiki Assistant 👩‍🏫: Red Bull  (score=0.61022)
#
# ...

# %%
chat(modelo_pre_trained_roberta)
# Out:
# Wiki Assistant 👩‍🏫: Hello 😊, I am your virtual assistant from Wikipedia. What topic would you like to consult? (Write exit if you want to close the chat)
#            You 👉: Amazon Alexa
#
# Wiki Assistant 👩‍🏫: What would you like to know?
#            You 👉: What is Alexa?
# Wiki Assistant 👩‍🏫: a virtual assistant technology  (score=0.38293)
#
#            You 👉: Why her name is Alexa?
# Wiki Assistant 👩‍🏫: the name is reminiscent of the Library of Alexandria  (score=0.30133)
#
#            You 👉: What inspired the creation of Alexa?
# Wiki Assistant 👩‍🏫: speech recognition and natural language processing technology  (score=0.64749)
#
#            You 👉: I would like to change the topic
# Wiki Assistant 👩‍🏫: Of course😊, What other topic would you like to consult?
#            You 👉: Tayrona National Natural Park
#
# Wiki Assistant 👩‍🏫: What would you like to know?
#            You 👉: Where is it located?
# Wiki Assistant 👩‍🏫: Colombian northern Caribbean region  (score=0.31281)
#
# ...

# %% [markdown]
# # Pre entrenado T5

# %%
# %run 'c05_pre_trained_T5.ipynb'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# All model checkpoint layers were used when initializing TFT5ForConditionalGeneration.
#
# All the layers of TFT5ForConditionalGeneration were initialized from the model checkpoint at /content/gdrive/MyDrive/Transformers_files/scratch_T5_squad.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.

# %%
chat(modelo_pre_trained_T5)
# Out:
# Wiki Assistant 👩‍🏫: Hello 😊, I am your virtual assistant from Wikipedia. What topic would you like to consult? (Write exit if you want to close the chat)
#            You 👉: 2021 Formula One World Championship
#
# Wiki Assistant 👩‍🏫: What would you like to know?
#            You 👉: who driver took pole position in Spain?
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2310: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# ...

# %%
chat(modelo_pre_trained_T5)
# Out:
# Wiki Assistant 👩‍🏫: Hello 😊, I am your virtual assistant from Wikipedia. What topic would you like to consult? (Write exit if you want to close the chat)
#            You 👉: Amazon Alexa
#
# Wiki Assistant 👩‍🏫: What would you like to know?
#            You 👉: What is Alexa?
# Wiki Assistant 👩‍🏫: a virtual assistant technology
#
#            You 👉: Why her name is Alexa?
# Wiki Assistant 👩‍🏫: a Polish speech synthesiser named Ivona
#
#            You 👉: What inspired the creation of Alexa?
# Wiki Assistant 👩‍🏫: a Polish speech synthesiser named Ivona
#
#            You 👉: I would like to change the topic
# Wiki Assistant 👩‍🏫: Of course😊, What other topic would you like to consult?
#            You 👉: Tayrona National Natural Park
#
# Wiki Assistant 👩‍🏫: What would you like to know?
#            You 👉: Where is it located?
# Wiki Assistant 👩‍🏫: Colombian northern Caribbean region
#
#            You 👉: When was created?
# ...
